# %% [markdown]
# ### Crucible Growth of YVO<sub>4</sub> from V<sub>2</sub>O<sub>5</sub> and Y<sub>2</sub>O<sub>3</sub> in Air
# YVO4 was grown in an alumina crucible from Y and V oxides using a furnace.
#
# The purpose of the experiment was to test the effects of vanadium deficiency on phase formation.
# This is experiment is a continuation of GBM1003 implementing the pellet press.
#
# Performed starting 2023-06-13 @ ML by GBM

# %%
### Imports ###

from tools.attr_utils import *
from tools.block.Block import Block
from tools.utilities import *

from utils.block_builders import *
from utils.base_builders import *
from utils.provenance import Provenance
from utils.mpurity import SOLNS

from gemd import FileLink
from gemd.json import GEMDJson
from gemd import NominalReal,UniformReal

from GBM1003 import GBM1003

import os
# Out:
# {'tags': [], 'uids': {}, 'name': 'Y2O3 Acquisition Process', 'file_links': [], 'template': {'tags': [], 'uids': {}, 'name': 'utils.block_builders', 'description': None, 'parameters': [[{'tags': [], 'uids': {}, 'name': 'Manufacturer', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Alfa Aesar', 'Fisher Chemical', 'Fisher Commercial', 'Noah Technologies Corporation', 'Strem Chemicals', 'Thermo Scientific', 'XYZ Chemicals', 'Yeemeida Technology Co. LTD']}, 'type': 'parameter_template'}, None], [{'tags': [], 'uids': {}, 'name': 'Lot ID', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['00000', '0198917/2.1', '182153', '221613', '23195800', 'R04D028', 'R10H008', 'W19F006', 'X17C007']}, 'type': 'parameter_template'}, None], [{'tags': [], 'uids': {}, 'name': 'CAS RN', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['000-00-000', '1314-36-9', '1314-62-1', '554-13-2', '7697-37-2']}, 'type': 'parameter_template'}, None]], 'allowed_labels': [], 'allowed_names': [], 'conditions': [], 'type': 'process_template'}, 'parameters': [], 'notes': None, 'conditions': [], 'type': 'process_spec', 'output_material': None, 'ingredients': []}
# {'tags': [], 'uids': {}, 'name': 'V2O5 Acquisition Process', 'file_links': [], 'template': {'tags': [], 'uids': {}, 'name': 'utils.block_builders', 'description': None, 'parameters': [[{'tags': [], 'uids': {}, 'name': 'Manufacturer', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Alfa Aesar', 'Fisher Chemical', 'Fisher Commercial', 'Noah Technologies Corporation', 'Strem Chemicals', 'Thermo Scientific', 'XYZ Chemicals', 'Yeemeida Technology Co. LTD']}, 'type': 'parameter_template'}, None], [{'tags': [], 'uids': {}, 'name': 'Lot ID', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['00000', '0198917/2.1', '182153', '221613', '23195800', 'R04D028', 'R10H008', 'W19F006', 'X17C007']}, 'type': 'parameter_template'}, None], [{'tags': [], 'uids': {}, 'name': 'CAS RN', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['000-00-000', '1314-36-9', '1314-62-1', '554-13-2', '7697-37-2']}, 'type': 'parameter_template'}, None]], 'allowed_labels': [], 'allowed_names': [], 'conditions': [], 'type': 'process_template'}, 'parameters': [], 'notes': None, 'conditions': [], 'type': 'process_spec', 'output_material': None, 'ingredients': []}
# {'tags': [], 'uids': {}, 'name': 'GBM1003A Grinding Process', 'file_links': [], 'template': {'tags': [], 'uids': {}, 'name': 'utils.base_builders', 'description': None, 'parameters': [[{'tags': [], 'uids': {}, 'name': 'Equipment Used', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Autoclave', 'Mortar and Pestle', 'Nichrome Wire', 'Pellet Press', 'Pellet Press Set', 'Quartz Tube', 'Quartz Wool', 'Thermocouple', 'Tongs', 'Torch', 'Tube Sealing Station', 'Vacuum Filter']}, 'type': 'parameter_template'}, None]], 'allowed_labels': [], 'allowed_names': [], 'conditions': [[{'tags': [], 'uids': {}, 'name': 'Location', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Bucket', 'Hot Lab', 'Purification Tube Furnace', 'Synthesis Tube Furnace', 'Three Zones Tube Furnace', 'Wet Lab', 'X-Ray Diffraction Panel']}, 'type': 'condition_template'}, None]], 'type': 'process_template'}, 'parameters': [], 'notes': None, 'conditions': [], 'type': 'process_spec', 'output_material': None, 'ingredients': []}
# {'tags': [], 'uids': {}, 'name': 'GBM1003B Grinding Process', 'file_links': [], 'template': {'tags': [], 'uids': {}, 'name': 'utils.base_builders', 'description': None, 'parameters': [[{'tags': [], 'uids': {}, 'name': 'Equipment Used', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Autoclave', 'Mortar and Pestle', 'Nichrome Wire', 'Pellet Press', 'Pellet Press Set', 'Quartz Tube', 'Quartz Wool', 'Thermocouple', 'Tongs', 'Torch', 'Tube Sealing Station', 'Vacuum Filter']}, 'type': 'parameter_template'}, None]], 'allowed_labels': [], 'allowed_names': [], 'conditions': [[{'tags': [], 'uids': {}, 'name': 'Location', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Bucket', 'Hot Lab', 'Purification Tube Furnace', 'Synthesis Tube Furnace', 'Three Zones Tube Furnace', 'Wet Lab', 'X-Ray Diffraction Panel']}, 'type': 'condition_template'}, None]], 'type': 'process_template'}, 'parameters': [], 'notes': None, 'conditions': [], 'type': 'process_spec', 'output_material': None, 'ingredients': []}
# {'tags': [], 'uids': {}, 'name': 'GBM1003C Grinding Process', 'file_links': [], 'template': {'tags': [], 'uids': {}, 'name': 'utils.base_builders', 'description': None, 'parameters': [[{'tags': [], 'uids': {}, 'name': 'Equipment Used', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Autoclave', 'Mortar and Pestle', 'Nichrome Wire', 'Pellet Press', 'Pellet Press Set', 'Quartz Tube', 'Quartz Wool', 'Thermocouple', 'Tongs', 'Torch', 'Tube Sealing Station', 'Vacuum Filter']}, 'type': 'parameter_template'}, None]], 'allowed_labels': [], 'allowed_names': [], 'conditions': [[{'tags': [], 'uids': {}, 'name': 'Location', 'description': None, 'bounds': {'type': 'categorical_bounds', 'categories': ['Bucket', 'Hot Lab', 'Purification Tube Furnace', 'Synthesis Tube Furnace', 'Three Zones Tube Furnace', 'Wet Lab', 'X-Ray Diffraction Panel']}, 'type': 'condition_template'}, None]], 'type': 'process_template'}, 'parameters': [], 'notes': None, 'conditions': [], 'type': 'process_spec', 'output_material': None, 'ingredients': []}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      13 from gemd.json import GEMDJson
#      14 from gemd import NominalReal,UniformReal
# ---> 16 from GBM1003 import GBM1003
#      18 import os
#
# File c:\Users\dev\PARADIM\YVO4_project\YVO4_project\GBM1003.py:198
#     194 ### Heating Blocks ###
#     196 for sample in ['GBM1003A','GBM1003B','GBM1003C']:
# --> 198     process = build_heating_process_base(
#     199         name=sample,
#     200         steps=5,
#     201         location='Hot Lab',
#     202         notes='All samples heated simultaneously',
#     203         prv=prv
#     204     )
#     206     material = build_heated_material_base(
#     207         name=sample,
#     208         process_spec=process.spec,
#    (...)
#     211         prv=prv
#     212     )
#     214     ingredients = [
#     215         build_ingredient_base(
#     216             name=sample,
#    (...)
#     223         )
#     224     ]
#
# File c:\Users\dev\PARADIM\YVO4_project\YVO4_project\utils\base_builders.py:96, in build_heating_process_base(name, steps, location, notes, workflow, prv)
#      82 def build_heating_process_base(name:str,steps:int,location:str,notes:str=None,workflow:Workflow=None,prv:Provenance=None):
#      83     """
#      84     Builds a basenode for heating a material.
#      85
#    (...)
#      93         ex: Provenance()
#      94     """
# ---> 96     process_spec = build_heating_material_proc_spec(
#      97         name=name,
#      98         steps=steps,
#      99         location=location,
#     100         notes=notes
#     101     )
#     103     process_run = ProcessRun(
#     104         name=name,
#     105         spec=process_spec,
#    (...)
#     108         source= PerformedSource(prv.email,prv.date)
#     109     )
#     111     class HeatingProcess(Process):
#
# File c:\Users\dev\PARADIM\YVO4_project\YVO4_project\utils\spec_builders.py:279, in build_heating_material_proc_spec(name, steps, location, notes)
#     272 STEPS = []
#     274 for i in range(steps):
#     275     STEPS.append(
#     276         {
#     277         'Number':int(i+1),
#     278         'Type':str(input(f'Step {i+1} Type (Init,Ramp,Hold,End):')),
# --> 279         'Temp':float(input(f'Step {i+1} Temperature (degC):')),
#     280         'Duration':float(input(f'Step {i+1} Duration (hours):'))
#     281         }
#     282     )
#     284     attr_validate('Step Type',STEPS[i]['Type'])
#     286     PROCESS_SPECS[f'Heating {name} Spec'].parameters.append(Parameter(
#     287         name=f'Step {i}',
#     288         template=ATTR_TEMPL['Step'],
#    (...)
#     292         )
#     293     )
#
# ValueError: could not convert string to float: ''

# %%
### Provenance ###

prv = Provenance(
    name='Gannon Murray',
    email='gmurra12@jh.edu',
    tag='GBM',
    page='1005',
    title='Crucible Growth of YVO4',
    date='2023-06-13'
)

# %%
### Workflow ###

GBM1005 = {}

# %%
### Pressing Process ###

sample = 'GBM1005A'

process = build_pressing_process_base(
    name=sample,
    location='Hot Lab',
    equipment='Pellet Press',
    pressure=27.5,
    duration=0.1,
    prv=prv
)

material = build_pressed_material_base(
    name=sample,
    process_spec=process.spec,
    process_run=process.run,
    form='Pellet',
    prv=prv
)

ingredients = [
    build_ingredient_base(
        name='GBM1003A',
        material_spec=GBM1003['heat_GBM1003A'].material.spec,
        material_run=GBM1003['heat_GBM1003A'].material.run,
        process_spec=process.spec,
        process_run=process.run,
        quantity_spec=NominalReal(370.5,'mg'),
        quantity_run = UniformReal(370.5-0.5,370.5+0.5,'mg')
    )
]

GBM1005[f'press_{sample}'] = Block(
    name=f'{sample} Press Block',
    ingredients=ingredients,
    process=process,
    material=material
)


sample = 'GBM1005B'

process = build_pressing_process_base(
    name=sample,
    location='Hot Lab',
    equipment='Pellet Press',
    pressure=27.5,
    duration=0.1,
    prv=prv
)

material = build_pressed_material_base(
    name=sample,
    process_spec=process.spec,
    process_run=process.run,
    form='Pellet',
    prv=prv
)

ingredients = [
    build_ingredient_base(
        name='GBM1003B',
        material_spec=GBM1003['heat_GBM1003B'].material.spec,
        material_run=GBM1003['heat_GBM1003B'].material.run,
        process_spec=process.spec,
        process_run=process.run,
        quantity_spec=NominalReal(374.8,'mg'),
        quantity_run = UniformReal(374.8-0.5,374.8+0.5,'mg')
    )
]

GBM1005[f'press_{sample}'] = Block(
    name=f'{sample} Press Block',
    ingredients=ingredients,
    process=process,
    material=material
)


sample = 'GBM1005C'

process = build_pressing_process_base(
    name=sample,
    location='Hot Lab',
    equipment='Pellet Press',
    pressure=27.5,
    duration=0.1,
    prv=prv
)

material = build_pressed_material_base(
    name=sample,
    process_spec=process.spec,
    process_run=process.run,
    form='Pellet',
    prv=prv
)

ingredients = [
    build_ingredient_base(
        name='GBM1003C',
        material_spec=GBM1003['heat_GBM1003C'].material.spec,
        material_run=GBM1003['heat_GBM1003C'].material.run,
        process_spec=process.spec,
        process_run=process.run,
        quantity_spec=NominalReal(339.0,'mg'),
        quantity_run = UniformReal(339.0-0.5,339.0+0.5,'mg')
    )
]

GBM1005[f'press_{sample}'] = Block(
    name=f'{sample} Press Block',
    ingredients=ingredients,
    process=process,
    material=material
)
